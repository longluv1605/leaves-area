# %% [markdown]
# # Download project

# %%
import os
import shutil

if 'leaves-area' in os.listdir():
    shutil.rmtree('leaves-area')
! git clone https://github.com/longluv1605/leaves-area
# Out:
# Cloning into 'leaves-area'...
# remote: Enumerating objects: 233, done.
# remote: Counting objects: 100% (156/156), done.
# remote: Compressing objects: 100% (111/111), done.
# remote: Total 233 (delta 68), reused 121 (delta 38), pack-reused 77 (from 1)
# Receiving objects: 100% (233/233), 43.65 MiB | 18.43 MiB/s, done.
# Resolving deltas: 100% (76/76), done.

# %%
print(os.getcwd())
if os.getcwd() == '/kaggle/working':
    os.chdir('leaves-area')
    print(os.getcwd())
# Out:
# /kaggle/working
# /kaggle/working/leaves-area

# %% [markdown]
# # Segmentation

# %%
# !python src/dl_method/main.py
# Out:
# /usr/local/lib/python3.11/dist-packages/albumentations/__init__.py:28: UserWarning: A new version of Albumentations is available: '2.0.6' (you have '2.0.4'). Upgrade using: pip install -U albumentations. To disable automatic update checks, set the environment variable NO_ALBUMENTATIONS_UPDATE to 1.
#   check_for_updates()
# [Epoch 1/10]
# ...
# Evaluating metrics: 100%|████████████████████| 10/10 [00:02<00:00,  4.78batch/s]
# 	-> Train Loss: 0.3575, mIoU: 0.6865, Acc: 0.9531
# 	-> Val Loss: 0.2812, mIoU: 0.6840, Acc: 0.9545
# #################################################################
# Saved model to save/models/model_20250505_174929.pth!!!
# [Epoch 2/10]
# ...
# Evaluating metrics: 100%|████████████████████| 10/10 [00:02<00:00,  4.45batch/s]
# 	-> Train Loss: 0.2521, mIoU: 0.8349, Acc: 0.9672
# 	-> Val Loss: 0.2178, mIoU: 0.8232, Acc: 0.9684
# #################################################################
# Saved model to save/models/model_20250505_174929.pth!!!
# [Epoch 3/10]
# ...
